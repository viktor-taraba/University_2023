# %%
# !pip install pytickersymbols
# Out:
# ...
# [notice] A new release of pip is available: 23.3 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#      -------------------------------------- 79.5/79.5 kB 261.4 kB/s eta 0:00:00
# ...
#      ------------------------------------ 153.2/153.2 kB 212.7 kB/s eta 0:00:00
# ...
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.36.2
#     Uninstalling wheel-0.36.2:
#       Successfully uninstalled wheel-0.36.2
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 5.4.1
#     Uninstalling PyYAML-5.4.1:
#       Successfully uninstalled PyYAML-5.4.1
# ...

# %%
from pytickersymbols import PyTickerSymbols

# %%
stock_data = PyTickerSymbols()
sp100_stocks = stock_data.get_stocks_by_index('S&P 100')
print(list(sp100_stocks))
# Out:
# [{'name': 'Linde PLC', 'symbol': 'LIN', 'country': 'United Kingdom', 'indices': ['DAX', 'EURO STOXX 50', 'S&P 100', 'S&P 500'], 'industries': ['Commodity Chemicals', 'Basic Materials', 'Chemicals'], 'symbols': [{'yahoo': 'LIN.F', 'google': 'FRA:LIN', 'currency': 'EUR'}, {'yahoo': 'LIN', 'google': 'NYSE:LIN', 'currency': 'USD'}], 'metadata': {'founded': 1879, 'employees': 74207}, 'isins': ['IE00BZ12WP82'], 'akas': []}, {'name': '3M Company', 'symbol': 'MMM', 'country': 'United States', 'indices': ['DOW JONES', 'S&P 100', 'S&P 500'], 'industries': ['Industrials', 'Industrial Conglomerates'], 'symbols': [{'yahoo': 'MMM.F', 'google': 'FRA:MMM', 'currency': 'EUR'}, {'yahoo': 'MMM', 'google': 'NYSE:MMM', 'currency': 'USD'}], 'metadata': {'founded': 1902, 'employees': 94987}, 'isins': ['US88579Y1010'], 'akas': []}, {'name': 'American Express Company', 'symbol': 'AXP', 'country': 'United States', 'indices': ['DOW JONES', 'S&P 100', 'S&P 500'], 'industries': ['Banking & Investment Services', 
# ...

# %%
import pandas as pd
sp100_stocks = stock_data.get_stocks_by_index('S&P 100')
df_stock_tickers = pd.DataFrame(list(sp100_stocks))
df_stock_tickers.head()
# Out:
#                        name symbol         country  \
# 0                 Linde PLC    LIN  United Kingdom
# 1                3M Company    MMM   United States
# 2  American Express Company    AXP   United States
# 3                Apple Inc.   AAPL   United States
# 4        The Boeing Company     BA   United States
#
#                                              indices  \
# 0             [DAX, EURO STOXX 50, S&P 100, S&P 500]
# 1                      [DOW JONES, S&P 100, S&P 500]
# 2                      [DOW JONES, S&P 100, S&P 500]
# 3          [DOW JONES, NASDAQ 100, S&P 100, S&P 500]
# 4  [CAC 40, DOW JONES, EURO STOXX 50, S&P 100, S&...
#
#                                           industries  \
# 0  [Commodity Chemicals, Basic Materials, Chemicals]
# 1            [Industrials, Industrial Conglomerates]
# 2  [Banking & Investment Services, Banking Servic...
# 3  [Computers, Phones & Household Electronics, Te...
# 4  [Industrial Goods, Industrials, Aerospace & De...
#
# ...

# %%
df_stock_tickers.describe()
# Out:
#              name symbol        country             indices  \
# count         100    100            100                 100
# unique        100    100              4                   8
# top     Linde PLC    LIN  United States  [S&P 100, S&P 500]
# freq            1      1             96                  46
#
#                                                industries  \
# count                                                 100
# unique                                                 55
# top     [Pharmaceuticals, Pharmaceuticals & Medical Re...
# freq                                                    7
#
#                                                   symbols  \
# count                                                 100
# unique                                                100
# top     [{'yahoo': 'LIN.F', 'google': 'FRA:LIN', 'curr...
# freq                                                    1
#
#                                      metadata isins akas   wiki_name
# ...

# %%
df_stock_tickers[['name','symbol']]
# Out:
#                             name symbol
# 0                      Linde PLC    LIN
# 1                     3M Company    MMM
# 2       American Express Company    AXP
# 3                     Apple Inc.   AAPL
# 4             The Boeing Company     BA
# ..                           ...    ...
# 95                      Dow Inc.    DOW
# 96  General Dynamics Corporation     GD
# 97   Lockheed Martin Corporation    LMT
# 98                 PepsiCo, Inc.    PEP
# 99          Meta Platforms, Inc.   META
#
# [100 rows x 2 columns]

# %%
df_stock_tickers.to_csv('tickers.csv')

# %% [markdown]
# S&P 500 constituent Deere & Co. (NYSE:DE) will replace Walgreens Boots Alliance Inc. (NASD:WBA) in the S&P 100. Walgreens Boots Alliance is no longer representative of the mega-cap market space. Walgreens Boots Alliance will remain in the S&P 500.

# %%
import pandas as pd
sp500_stocks = stock_data.get_stocks_by_index('S&P 500')
df_stock_tickers_full = pd.DataFrame(list(sp500_stocks))
df_stock_tickers_full.head()
# Out:
#                        name symbol         country  \
# 0                 Linde PLC    LIN  United Kingdom
# 1      Carnival Corporation    CCL  United Kingdom
# 2                STERIS PLC    SSE  United Kingdom
# 3                3M Company    MMM   United States
# 4  American Express Company    AXP   United States
#
#                                   indices  \
# 0  [DAX, EURO STOXX 50, S&P 100, S&P 500]
# 1                               [S&P 500]
# 2                               [S&P 500]
# 3           [DOW JONES, S&P 100, S&P 500]
# 4           [DOW JONES, S&P 100, S&P 500]
#
#                                           industries  \
# 0  [Commodity Chemicals, Basic Materials, Chemicals]
# 1  [Hotels & Entertainment Services, Cyclical Con...
# 2  [Electric Utilities, Electric Utilities & IPPs...
# 3            [Industrials, Industrial Conglomerates]
# 4  [Banking & Investment Services, Banking Servic...
#
#                                              symbols  \
# ...

# %%
df_stock_tickers_full.describe()
# Out:
#              name symbol        country    indices industries symbols  \
# count         499    499            499        499        499     499
# unique        499    498              9         11        154     498
# top     Linde PLC    DOW  United States  [S&P 500]         []      []
# freq            1      2            473        350         24       2
#
#                                      metadata isins akas   wiki_name
# count                                     499   499  499          88
# unique                                    494   105    1          88
# top     {'founded': 1911, 'employees': 92000}    []   []  Nike, Inc.
# freq                                        2   395  499           1

# %%
df_stock_tickers_full[(df_stock_tickers_full["symbol"]=='DE')]
# Out:
#                 name symbol        country    indices  \
# 214  Deere & Company     DE  United States  [S&P 500]
#
#                                             industries  \
# 214  [Industrial Goods, Industrials, Heavy Machiner...
#
#                                                symbols  \
# 214  [{'yahoo': 'DCO.F', 'google': 'FRA:DCO', 'curr...
#
#                                   metadata isins akas wiki_name
# 214  {'founded': 1837, 'employees': 69600}    []   []       NaN

# %%
df_stock_tickers[(df_stock_tickers["symbol"]=='DE')]
# Out:
# Empty DataFrame
# Columns: [name, symbol, country, indices, industries, symbols, metadata, isins, akas, wiki_name]
# Index: []

# %%
df_stock_tickers[(df_stock_tickers["symbol"]=='RTN')]
# Out:
#                 name symbol        country             indices  \
# 81  Raytheon Company    RTN  United States  [S&P 100, S&P 500]
#
#                                            industries  \
# 81  [Industrial Goods, Industrials, Aerospace & De...
#
#                                               symbols  \
# 81  [{'yahoo': 'RTN1.F', 'google': 'FRA:RTN1', 'cu...
#
#                                   metadata isins akas wiki_name
# 81  {'founded': 2020, 'employees': 195000}    []   []       NaN

# %%
df_stock_tickers[(df_stock_tickers["symbol"]=='RTX')]
# Out:
# Empty DataFrame
# Columns: [name, symbol, country, indices, industries, symbols, metadata, isins, akas, wiki_name]
# Index: []

# %%
https://www.ishares.com/us/products/239723/ishares-sp-100-etf/1467271812596.ajax?fileType=csv&fileName=OEF_holdings&dataType=fund

# %%
url = 'https://www.ishares.com/us/products/239723/ishares-sp-100-etf/1467271812596.ajax?fileType=csv&fileName=OEF_holdings&dataType=fund'
df_sp_100_etf = pd.read_csv(url, skiprows=9)
df_sp_100_etf
# Out:
#                                                 Ticker  \
# 0                                                 AAPL
# 1                                                 MSFT
# 2                                                 AMZN
# 3                                                 NVDA
# 4                                                GOOGL
# ..                                                 ...
# 103                                              MSFUT
# 104                                               ESH4
# 105                                         MARGIN_USD
# 106
# 107  The content contained herein is owned or licen...
#
#                            Name                   Sector  \
# 0                     APPLE INC   Information Technology
# 1                MICROSOFT CORP   Information Technology
# 2                AMAZON COM INC   Consumer Discretionary
# 3                   NVIDIA CORP   Information Technology
# 4          ALPHABET INC CLASS A            Communication
# ...

# %%
df_sp_100_etf.loc[df_sp_100_etf['Sector'] == 'Cash and/or Derivatives']
# Out:
#          Ticker                            Name                   Sector  \
# 90        XTSLA  BLK CSH FND TREASURY SL AGENCY  Cash and/or Derivatives
# 102         USD                        USD CASH  Cash and/or Derivatives
# 103       MSFUT       CASH COLLATERAL MSFUT USD  Cash and/or Derivatives
# 104        ESH4             S&P500 EMINI MAR 24  Cash and/or Derivatives
# 105  MARGIN_USD      FUTURES USD MARGIN BALANCE  Cash and/or Derivatives
#
#                      Asset Class   Market Value  Weight (%) Notional Value  \
# 90                  Money Market  23,794,575.87        0.19  23,794,575.87
# 102                         Cash   7,289,349.39        0.06   7,289,349.39
# 103  Cash Collateral and Margins   1,770,640.00        0.01   1,770,640.00
# 104                      Futures           0.00        0.00  32,535,000.00
# 105  Cash Collateral and Margins     -82,687.50        0.00     -82,687.50
#
#             Shares     Price       Location                  Exchange  \
# ...

# %%
df_sp_100_etf.iloc[106:108]
# Out:
#                                                 Ticker Name Sector  \
# 106                                                     NaN    NaN
# 107  The content contained herein is owned or licen...  NaN    NaN
#
#     Asset Class Market Value  Weight (%) Notional Value Shares Price Location  \
# 106         NaN          NaN         NaN            NaN    NaN   NaN      NaN
# 107         NaN          NaN         NaN            NaN    NaN   NaN      NaN
#
#     Exchange Currency  FX Rate Market Currency Accrual Date
# 106      NaN      NaN      NaN             NaN          NaN
# 107      NaN      NaN      NaN             NaN          NaN

# %%
df_sp_100_etf = df_sp_100_etf.iloc[1:106]
df_sp_100_etf
# Out:
#          Ticker                        Name                   Sector  \
# 1          MSFT              MICROSOFT CORP   Information Technology
# 2          AMZN              AMAZON COM INC   Consumer Discretionary
# 3          NVDA                 NVIDIA CORP   Information Technology
# 4         GOOGL        ALPHABET INC CLASS A            Communication
# 5          META  META PLATFORMS INC CLASS A            Communication
# ..          ...                         ...                      ...
# 101         KHC                 KRAFT HEINZ         Consumer Staples
# 102         USD                    USD CASH  Cash and/or Derivatives
# 103       MSFUT   CASH COLLATERAL MSFUT USD  Cash and/or Derivatives
# 104        ESH4         S&P500 EMINI MAR 24  Cash and/or Derivatives
# 105  MARGIN_USD  FUTURES USD MARGIN BALANCE  Cash and/or Derivatives
#
#                      Asset Class      Market Value  Weight (%)  \
# 1                         Equity  1,298,464,615.84       10.32
# ...

# %%
df_sp_100_etf = df_sp_100_etf.loc[df_sp_100_etf['Sector'] != 'Cash and/or Derivatives']

# %%
df_sp_100_etf
# Out:
#     Ticker                                Name                  Sector  \
# 1     MSFT                      MICROSOFT CORP  Information Technology
# 2     AMZN                      AMAZON COM INC  Consumer Discretionary
# 3     NVDA                         NVIDIA CORP  Information Technology
# 4    GOOGL                ALPHABET INC CLASS A           Communication
# 5     META          META PLATFORMS INC CLASS A           Communication
# ..     ...                                 ...                     ...
# 97      BK        BANK OF NEW YORK MELLON CORP              Financials
# 98    CHTR  CHARTER COMMUNICATIONS INC CLASS A           Communication
# 99     DOW                             DOW INC               Materials
# 100    EXC                         EXELON CORP               Utilities
# 101    KHC                         KRAFT HEINZ        Consumer Staples
#
#     Asset Class      Market Value  Weight (%)    Notional Value        Shares  \
# ...

# %%
df_sp_100_etf = df_sp_100_etf.drop(columns=['Accrual Date', 'Asset Class', 'Weight (%)', 'Notional Value', 'Location', 'Exchange', 'Currency', 'FX Rate', 'Market Currency'])
df_sp_100_etf.head()
# Out:
#   Ticker                        Name                  Sector  \
# 1   MSFT              MICROSOFT CORP  Information Technology
# 2   AMZN              AMAZON COM INC  Consumer Discretionary
# 3   NVDA                 NVIDIA CORP  Information Technology
# 4  GOOGL        ALPHABET INC CLASS A           Communication
# 5   META  META PLATFORMS INC CLASS A           Communication
#
#        Market Value        Shares   Price
# 1  1,298,464,615.84  3,452,996.00  376.04
# 2    641,947,563.58  4,225,007.00  151.94
# 3    568,289,711.00  1,147,550.00  495.22
# 4    384,074,442.13  2,749,477.00  139.69
# 5    365,010,277.24  1,031,219.00  353.96
