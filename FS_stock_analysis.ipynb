# %%
import lxml
import requests
import pandas as pd
from sqlalchemy import create_engine
import urllib

# %%
quoted = urllib.parse.quote_plus("Driver={SQL Server Native Client 11.0};Server=VIKTOR-PC-2001;Database=DividendPolicyResearch;Trusted_Connection=yes;")
engine = create_engine('mssql+pyodbc:///?odbc_connect={}'.format(quoted))
result = engine.execute("SELECT [Ticker] FROM [dbo].[tb_sp100_tickers]")
df_SP100_companies = pd.DataFrame(result.fetchall())
tickers_list = df_SP100_companies.iloc[:, 0].tolist()
tickers_list
# Out:
# ['AAPL',
#  'ABBV',
#  'ABT',
#  'ACN',
#  'ADBE',
#  'AIG',
#  'AMD',
#  'AMGN',
#  'AMT',
#  'AMZN',
#  'AVGO',
#  'AXP',
#  'BA',
#  'BAC',
#  'BK',
#  'BKNG',
#  'BLK',
#  'BMY',
#  'BRK-B',
#  'C',
#  'CAT',
#  'CHTR',
#  'CL',
#  'CMCSA',
#  'COF',
#  'COP',
#  'COST',
#  'CRM',
#  'CSCO',
#  'CVS',
#  'CVX',
#  'DE',
#  'DHR',
#  'DIS',
#  'DOW',
#  'DUK',
#  'EMR',
#  'EXC',
#  'F',
#  'FDX',
#  'GD',
#  'GE',
#  'GILD',
#  'GM',
#  'GOOG',
#  'GOOGL',
#  'GS',
#  'HD',
#  'HON',
#  'IBM',
#  'INTC',
#  'JNJ',
#  'JPM',
#  'KHC',
#  'KO',
#  'LIN',
#  'LLY',
#  'LMT',
#  'LOW',
#  'MA',
#  'MCD',
#  'MDLZ',
#  'MDT',
#  'MET',
#  'META',
#  'MMM',
#  'MO',
#  'MRK',
#  'MS',
#  'MSFT',
#  'NEE',
#  'NFLX',
#  'NKE',
#  'NVDA',
#  'ORCL',
#  'PEP',
#  'PFE',
#  'PG',
#  'PM',
#  'PYPL',
#  'QCOM',
#  'RTX',
#  'SBUX',
#  'SCHW',
#  'SO',
#  'SPG',
#  'T',
#  'TGT',
#  'TMO',
#  'TMUS',
#  'TSLA',
#  'TXN',
#  'UNH',
#  'UNP',
#  'UPS',
#  'USB',
#  'V',
#  'VZ',
#  'WFC',
# ...

# %%
print(len(tickers_list))
# Out:
# 101

# %%
for ticker in tickers_list:
    ticker = ticker.replace("-",".")
    print("Тікер: " + ticker)
    url = 'https://stockanalysis.com/stocks/'+ticker+'/financials/'

    r = requests.get(url)
    df_list = pd.read_html(r.text)
    df = df_list[0]
    df = df.rename(columns={"Year":"FSLI"})
    df.pop(df.columns[-1])
    df['ticker_name'] = ticker.replace(".","-")
    df["FS_type"] = "PL"
    
    print("К-ть стовпців: " + str(len(df.axes[1])))
    print("К-ть рядків: " + str(len(df.axes[0])))    
    
    df.to_sql('tb_FS_stock_analysis', schema='dbo', con = engine, if_exists='append',index=False)

    print("")
# Out:
# Тікер: AAPL
# К-ть стовпців: 13
# К-ть рядків: 34
#
# Тікер: ABBV
# К-ть стовпців: 13
# К-ть рядків: 35
#
# Тікер: ABT
# К-ть стовпців: 13
# К-ть рядків: 35
#
# Тікер: ACN
# К-ть стовпців: 13
# К-ть рядків: 34
#
# Тікер: ADBE
# К-ть стовпців: 13
# К-ть рядків: 33
#
# Тікер: AIG
# К-ть стовпців: 13
# К-ть рядків: 36
#
# Тікер: AMD
# К-ть стовпців: 13
# К-ть рядків: 33
#
# Тікер: AMGN
# К-ть стовпців: 13
# К-ть рядків: 35
#
# Тікер: AMT
# К-ть стовпців: 13
# К-ть рядків: 36
#
# Тікер: AMZN
# К-ть стовпців: 13
# К-ть рядків: 33
#
# Тікер: AVGO
# К-ть стовпців: 13
# К-ть рядків: 37
#
# Тікер: AXP
# К-ть стовпців: 13
# К-ть рядків: 31
#
# Тікер: BA
# К-ть стовпців: 13
# К-ть рядків: 34
#
# Тікер: BAC
# К-ть стовпців: 13
# К-ть рядків: 34
#
# Тікер: BK
# К-ть стовпців: 13
# К-ть рядків: 34
#
# Тікер: BKNG
# К-ть стовпців: 13
# К-ть рядків: 32
#
# Тікер: BLK
# К-ть стовпців: 13
# К-ть рядків: 34
#
# Тікер: BMY
# К-ть стовпців: 13
# К-ть рядків: 33
#
# Тікер: BRK.B
# К-ть стовпців: 13
# ...

# %%
for ticker in tickers_list:
    ticker = ticker.replace("-",".")
    print("Тікер: " + ticker)
    url = 'https://stockanalysis.com/stocks/'+ticker+'/financials/cash-flow-statement/'

    r = requests.get(url)
    df_list = pd.read_html(r.text)
    df = df_list[0]
    df = df.rename(columns={"Year":"FSLI"})
    df.pop(df.columns[-1])
    df['ticker_name'] = ticker.replace(".","-")
    df["FS_type"] = "CF"
    
    print("К-ть стовпців: " + str(len(df.axes[1])))
    print("К-ть рядків: " + str(len(df.axes[0])))    
    
    df.to_sql('tb_FS_stock_analysis', schema='dbo', con = engine, if_exists='append',index=False)

    print("")
# Out:
# Тікер: AAPL
# К-ть стовпців: 13
# К-ть рядків: 21
#
# Тікер: ABBV
# К-ть стовпців: 13
# К-ть рядків: 22
#
# Тікер: ABT
# К-ть стовпців: 13
# К-ть рядків: 22
#
# Тікер: ACN
# К-ть стовпців: 13
# К-ть рядків: 21
#
# Тікер: ADBE
# К-ть стовпців: 13
# К-ть рядків: 20
#
# Тікер: AIG
# К-ть стовпців: 13
# К-ть рядків: 20
#
# Тікер: AMD
# К-ть стовпців: 13
# К-ть рядків: 20
#
# Тікер: AMGN
# К-ть стовпців: 13
# К-ть рядків: 21
#
# Тікер: AMT
# К-ть стовпців: 13
# К-ть рядків: 22
#
# Тікер: AMZN
# К-ть стовпців: 13
# К-ть рядків: 20
#
# Тікер: AVGO
# К-ть стовпців: 13
# К-ть рядків: 21
#
# Тікер: AXP
# К-ть стовпців: 13
# К-ть рядків: 22
#
# Тікер: BA
# К-ть стовпців: 13
# К-ть рядків: 22
#
# Тікер: BAC
# К-ть стовпців: 13
# К-ть рядків: 20
#
# Тікер: BK
# К-ть стовпців: 13
# К-ть рядків: 21
#
# Тікер: BKNG
# К-ть стовпців: 13
# К-ть рядків: 21
#
# Тікер: BLK
# К-ть стовпців: 13
# К-ть рядків: 21
#
# Тікер: BMY
# К-ть стовпців: 13
# К-ть рядків: 21
#
# Тікер: BRK.B
# К-ть стовпців: 13
# ...

# %%
for ticker in tickers_list:
    ticker = ticker.replace("-",".")
    print("Тікер: " + ticker)
    url = 'https://stockanalysis.com/stocks/'+ticker+'/financials/ratios/'

    r = requests.get(url)
    df_list = pd.read_html(r.text)
    df = df_list[0]
    df = df.rename(columns={"Year":"FSLI"})
    df.pop(df.columns[-1])
    df['ticker_name'] = ticker.replace(".","-")
    df["FS_type"] = "Ratios"
    df = df.drop('Current', axis=1)
    
    print("К-ть стовпців: " + str(len(df.axes[1])))
    print("К-ть рядків: " + str(len(df.axes[0])))    
    
    df.to_sql('tb_FS_stock_analysis', schema='dbo', con = engine, if_exists='append',index=False)

    print("")
# Out:
# Тікер: AAPL
# К-ть стовпців: 13
# К-ть рядків: 28
#
# Тікер: ABBV
# К-ть стовпців: 13
# К-ть рядків: 28
#
# Тікер: ABT
# К-ть стовпців: 13
# К-ть рядків: 28
#
# Тікер: ACN
# К-ть стовпців: 13
# К-ть рядків: 28
#
# Тікер: ADBE
# К-ть стовпців: 13
# К-ть рядків: 26
#
# Тікер: AIG
# К-ть стовпців: 13
# К-ть рядків: 26
#
# Тікер: AMD
# К-ть стовпців: 13
# К-ть рядків: 26
#
# Тікер: AMGN
# К-ть стовпців: 13
# К-ть рядків: 28
#
# Тікер: AMT
# К-ть стовпців: 13
# К-ть рядків: 28
#
# Тікер: AMZN
# К-ть стовпців: 13
# К-ть рядків: 26
#
# Тікер: AVGO
# К-ть стовпців: 13
# К-ть рядків: 28
#
# Тікер: AXP
# К-ть стовпців: 13
# К-ть рядків: 25
#
# Тікер: BA
# К-ть стовпців: 13
# К-ть рядків: 28
#
# Тікер: BAC
# К-ть стовпців: 13
# К-ть рядків: 25
#
# Тікер: BK
# К-ть стовпців: 13
# К-ть рядків: 25
#
# Тікер: BKNG
# К-ть стовпців: 13
# К-ть рядків: 28
#
# Тікер: BLK
# К-ть стовпців: 13
# К-ть рядків: 26
#
# Тікер: BMY
# К-ть стовпців: 13
# К-ть рядків: 27
#
# Тікер: BRK.B
# К-ть стовпців: 13
# ...

# %%
tickers_list = ['LIN', 'LLY', 'LMT', 'LOW', 'MA', 'MCD', 'MDLZ', 'MDT', 'MET', 'META', 'MMM', 'MO', 'MRK', 'MS', 'MSFT', 'NEE', 'NFLX', 'NKE', 'NVDA', 'ORCL', 'PEP', 'PFE', 'PG', 'PM', 'PYPL', 'QCOM', 'RTX', 'SBUX', 'SCHW', 'SO', 'SPG', 'T', 'TGT', 'TMO', 'TMUS', 'TSLA', 'TXN', 'UNH', 'UNP','UPS', 'USB', 'V', 'VZ','WFC', 'WMT','XOM']

# %%
for ticker in tickers_list:
    ticker = ticker.replace("-",".")
    print("Тікер: " + ticker)
    url = 'https://stockanalysis.com/stocks/'+ticker+'/financials/ratios/'

    r = requests.get(url)
    df_list = pd.read_html(r.text)
    df = df_list[0]
    df = df.rename(columns={"Year":"FSLI"})
    df.pop(df.columns[-1])
    df['ticker_name'] = ticker.replace(".","-")
    df["FS_type"] = "Ratios"
    df = df.drop('Current', axis=1)
    
    print("К-ть стовпців: " + str(len(df.axes[1])))
    print("К-ть рядків: " + str(len(df.axes[0])))    
    
    df.to_sql('tb_FS_stock_analysis', schema='dbo', con = engine, if_exists='append',index=False)

    print("")
# Out:
# Тікер: LIN
# К-ть стовпців: 9
# К-ть рядків: 28
#
# Тікер: LLY
# К-ть стовпців: 13
# К-ть рядків: 27
#
# Тікер: LMT
# К-ть стовпців: 13
# К-ть рядків: 28
#
# Тікер: LOW
# К-ть стовпців: 13
# К-ть рядків: 28
#
# Тікер: MA
# К-ть стовпців: 13
# К-ть рядків: 28
#
# Тікер: MCD
# К-ть стовпців: 13
# К-ть рядків: 28
#
# Тікер: MDLZ
# К-ть стовпців: 13
# К-ть рядків: 28
#
# Тікер: MDT
# К-ть стовпців: 13
# К-ть рядків: 28
#
# Тікер: MET
# К-ть стовпців: 13
# К-ть рядків: 25
#
# Тікер: META
# К-ть стовпців: 13
# К-ть рядків: 27
#
# Тікер: MMM
# К-ть стовпців: 13
# К-ть рядків: 28
#
# Тікер: MO
# К-ть стовпців: 13
# К-ть рядків: 28
#
# Тікер: MRK
# К-ть стовпців: 13
# К-ть рядків: 28
#
# Тікер: MS
# К-ть стовпців: 13
# К-ть рядків: 25
#
# Тікер: MSFT
# К-ть стовпців: 13
# К-ть рядків: 28
#
# Тікер: NEE
# К-ть стовпців: 13
# К-ть рядків: 28
#
# Тікер: NFLX
# К-ть стовпців: 13
# К-ть рядків: 26
#
# Тікер: NKE
# К-ть стовпців: 13
# К-ть рядків: 28
#
# Тікер: NVDA
# К-ть стовпців: 13
# ...
