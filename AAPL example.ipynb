# %%
import pandas as pd

# %%
df_sub = pd.read_csv('d:\Універ М\SEC data 2022\sub.txt', sep="\t")

# %%
df_sub.head()
# Out:
#                    adsh    cik                    name     sic countryba  \
# 0  0000014707-22-000072  14707             CALERES INC  3140.0        US
# 1  0000014846-22-000059  14846    BRT APARTMENTS CORP.  6798.0        US
# 2  0000018349-22-000191  18349  SYNOVUS FINANCIAL CORP  6021.0        US
# 3  0000035527-22-000248  35527     FIFTH THIRD BANCORP  6022.0        US
# 4  0000041719-22-000063  41719         GLATFELTER CORP  2621.0        US
#
#   stprba      cityba       zipba                  bas1                bas2  \
# 0     MO    ST LOUIS       63105     8300 MARYLAND AVE          P O BOX 29
# 1     NY  GREAT NECK  11021-3190     60 CUTTER MILL RD           SUITE 303
# 2     GA    COLUMBUS       31901       1111 BAY AVENUE             STE 500
# 3     OH  CINCINNATI       45263    38 FOUNTAIN SQ PLZ  FIFTH THIRD CENTER
# 4     NC   CHARLOTTE       28209  4350 CONGRESS STREET           SUITE 600
#
#    ...      period      fy   fp     filed               accepted prevrpt  \
# ...

# %%
df_sub.loc[(df['cik'] == 320193) & (df['fp'] == 'FY') & (df['fy'] == 2022)]
# Out:
#                        adsh     cik       name     sic countryba stprba  \
# 18461  0000320193-22-000108  320193  APPLE INC  3571.0        US     CA
#
#           cityba  zipba                bas1 bas2  ...      period      fy  fp  \
# 18461  CUPERTINO  95014  ONE APPLE PARK WAY  NaN  ...  20220930.0  2022.0  FY
#
#           filed               accepted prevrpt detail               instance  \
# 18461  20221028  2022-10-27 18:01:00.0       0      1  aapl-20220924_htm.xml
#
#       nciks  aciks
# 18461     1    NaN
#
# [1 rows x 36 columns]

# %%
df_num = pd.read_csv(r'd:\Універ М\SEC data 2022\num.txt', sep="\t")

# %%
df_num.head()
# Out:
#                    adsh                                                tag  \
# 0  0001140361-22-040133        AcceleratedShareRepurchaseProgramAdjustment
# 1  0001140361-22-040134        AcceleratedShareRepurchaseProgramAdjustment
# 2  0001140361-22-040134        AcceleratedShareRepurchaseProgramAdjustment
# 3  0001628280-22-028255        AcceleratedShareRepurchaseProgramAdjustment
# 4  0000860413-22-000202  AcceleratedShareRepurchasesAdjustmentToRecorde...
#
#         version coreg     ddate  qtrs  uom        value footnote
# 0  us-gaap/2021   NaN  20220331     1  USD -150000000.0      NaN
# 1  us-gaap/2021   NaN  20220331     1  USD -150000000.0      NaN
# 2  us-gaap/2021   NaN  20220630     1  USD          0.0      NaN
# 3  us-gaap/2021   NaN  20220930     1  USD   20010000.0      NaN
# 4  us-gaap/2021   NaN  20220930     3  USD  197400000.0      NaN

# %%
df_num[(df_num['adsh']=='0000320193-22-000108')]
# Out:
#                          adsh  \
# 258071   0000320193-22-000108
# 259078   0000320193-22-000108
# 265160   0000320193-22-000108
# 265161   0000320193-22-000108
# 281478   0000320193-22-000108
# ...                       ...
# 2341197  0000320193-22-000108
# 2341198  0000320193-22-000108
# 2341199  0000320193-22-000108
# 2341200  0000320193-22-000108
# 2341201  0000320193-22-000108
#
#                                                        tag  \
# 258071                  EntityCommonStockSharesOutstanding
# 259078                                   EntityPublicFloat
# 265160                              AccountsPayableCurrent
# 265161                              AccountsPayableCurrent
# 281478                        AccountsReceivableNetCurrent
# ...                                                    ...
# 2341197  OtherComprehensiveIncomeLossDerivativeInstrume...
# 2341198               PerformanceObligationsinArrangements
# ...

# %%
df_num[(df_num['adsh']=='0000320193-22-000108') & (df_num['tag']=='NetIncomeLoss')]
# Out:
#                          adsh            tag       version coreg     ddate  \
# 1427920  0000320193-22-000108  NetIncomeLoss  us-gaap/2022   NaN  20220930
# 1427921  0000320193-22-000108  NetIncomeLoss  us-gaap/2022   NaN  20200930
# 1427922  0000320193-22-000108  NetIncomeLoss  us-gaap/2022   NaN  20210930
#
#          qtrs  uom         value footnote
# 1427920     4  USD  9.980300e+10      NaN
# 1427921     4  USD  5.741100e+10      NaN
# 1427922     4  USD  9.468000e+10      NaN

# %%
df_num[(df_num['adsh']=='0000320193-22-000108') & (df_num['tag'].str.contains('RevenueFromContractWithCustomer', na=False))]
# Out:
#                          adsh  \
# 1991881  0000320193-22-000108
# 1991882  0000320193-22-000108
# 1991883  0000320193-22-000108
#
#                                                        tag       version  \
# 1991881  RevenueFromContractWithCustomerExcludingAssess...  us-gaap/2022
# 1991882  RevenueFromContractWithCustomerExcludingAssess...  us-gaap/2022
# 1991883  RevenueFromContractWithCustomerExcludingAssess...  us-gaap/2022
#
#         coreg     ddate  qtrs  uom         value footnote
# 1991881   NaN  20220930     4  USD  3.943280e+11      NaN
# 1991882   NaN  20200930     4  USD  2.745150e+11      NaN
# 1991883   NaN  20210930     4  USD  3.658170e+11      NaN

# %%
df_num[(df_num['adsh']=='0000320193-22-000108') & (df_num['tag']=='PaymentsOfDividends')]
# Out:
#                          adsh                  tag       version coreg  \
# 1743023  0000320193-22-000108  PaymentsOfDividends  us-gaap/2022   NaN
# 1743024  0000320193-22-000108  PaymentsOfDividends  us-gaap/2022   NaN
# 1743025  0000320193-22-000108  PaymentsOfDividends  us-gaap/2022   NaN
#
#             ddate  qtrs  uom         value footnote
# 1743023  20220930     4  USD  1.484100e+10      NaN
# 1743024  20210930     4  USD  1.446700e+10      NaN
# 1743025  20200930     4  USD  1.408100e+10      NaN

# %%
df_num[(df_num['adsh']=='0000320193-22-000108') & (df_num['tag']=='ComprehensiveIncomeNetOfTax')]
# Out:
#                         adsh                          tag       version coreg  \
# 607371  0000320193-22-000108  ComprehensiveIncomeNetOfTax  us-gaap/2022   NaN
# 607372  0000320193-22-000108  ComprehensiveIncomeNetOfTax  us-gaap/2022   NaN
# 607373  0000320193-22-000108  ComprehensiveIncomeNetOfTax  us-gaap/2022   NaN
#
#            ddate  qtrs  uom         value footnote
# 607371  20220930     4  USD  8.853100e+10      NaN
# 607372  20210930     4  USD  9.524900e+10      NaN
# 607373  20200930     4  USD  5.745300e+10      NaN
