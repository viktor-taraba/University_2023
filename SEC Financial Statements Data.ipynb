# %%
import pandas as pd
from sqlalchemy import create_engine
import urllib

# %%
year_param = 2013

# %%
quoted = urllib.parse.quote_plus("Driver={SQL Server Native Client 11.0};Server=VIKTOR-PC-2001;Database=DividendPolicyResearch;Trusted_Connection=yes;")
engine = create_engine('mssql+pyodbc:///?odbc_connect={}'.format(quoted))

# %%
result = engine.execute('SELECT [Ticker], cik_str FROM [dbo].[vw_tb_sp_tickers_with_CIK] where without_dividends = 0')
df_dividend_companies = pd.DataFrame(result.fetchall())
df_dividend_companies.columns = ['Ticker','cik']
df_dividend_companies = df_dividend_companies.set_index('cik')
df_dividend_companies.head()
# Out:
#         Ticker
# cik
# 320193    AAPL
# 1551152   ABBV
# 1800       ABT
# 1467373    ACN
# 5272       AIG

# %%
df_dividend_companies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88 entries, 320193 to 34088
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Ticker  88 non-null     object
# dtypes: object(1)
# memory usage: 1.4+ KB

# %%
df_sub1 = pd.read_csv(r'd:\Універ М\Диплом - Дивідендна політика корпорації\03_01\SEC data {}q4\sub4.txt'.format(year_param), sep="\t")
df_sub1 = df_sub1[(df_sub1['fp']=='FY')]
df_sub1.head()
# Out:
#                     adsh      cik  \
# 3   0001020859-13-000178  1020859
# 5   0001104659-13-073491  1250873
# 7   0001140361-13-037424   836429
# 8   0001193125-13-387152  1521847
# 12  0001213900-13-005507  1547521
#
#                                            name     sic countryba stprba  \
# 3                      UNITED NATURAL FOODS INC  5141.0        US     RI
# 5   CORPORATE PROPERTY ASSOCIATES 16 GLOBAL INC  6519.0        US     NY
# 7                           SYNERGETICS USA INC  3845.0        US     MO
# 8               MEMORIAL PRODUCTION PARTNERS LP  1311.0        US     TX
# 12                         ENGAGE MOBILITY, INC  7812.0        US     FL
#
#         cityba  zipba                         bas1        bas2  ...    period  \
# 3   PROVIDENCE  02908           313 IRON HORSE WAY         NaN  ...  20130731
# 5     NEW YORK  10020         50 ROCKEFELLER PLAZA         NaN  ...  20121231
# 7     O'FALLON  63368  3845 CORPORATE CENTRE DRIVE         NaN  ...  20130731
# ...

# %%
df_sub1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 795 entries, 3 to 7843
# Data columns (total 36 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   adsh        795 non-null    object
#  1   cik         795 non-null    int64
#  2   name        795 non-null    object
#  3   sic         793 non-null    float64
#  4   countryba   792 non-null    object
#  5   stprba      714 non-null    object
#  6   cityba      792 non-null    object
#  7   zipba       792 non-null    object
#  8   bas1        792 non-null    object
#  9   bas2        310 non-null    object
#  10  baph        793 non-null    object
#  11  countryma   791 non-null    object
#  12  stprma      719 non-null    object
#  13  cityma      791 non-null    object
#  14  zipma       791 non-null    object
#  15  mas1        791 non-null    object
#  16  mas2        313 non-null    object
#  17  countryinc  727 non-null    object
#  18  stprinc     703 non-null    object
# ...

# %%
df_sub2 = pd.read_csv(r'd:\Універ М\Диплом - Дивідендна політика корпорації\03_01\SEC data {}q4\sub3.txt'.format(year_param), sep="\t")
df_sub2 = df_sub2[(df_sub2['fp']=='FY')]
df_sub2.head()
# Out:
#                    adsh      cik                         name     sic  \
# 1  0000798359-13-000065   798359  INVESTORS REAL ESTATE TRUST  6798.0
# 3  0001002014-13-000279  1083706                   ENXNET INC  7372.0
# 4  0001002014-13-000281  1520592                STARFLICK.COM  7812.0
# 5  0001038838-13-000260   924805                BMB MUNAI INC  1311.0
# 6  0001038838-13-000261  1289636           PROFIRE ENERGY INC  3822.0
#
#   countryba stprba          cityba       zipba                           bas1  \
# 1        US     ND           MINOT  58702-1988  1400 31ST AVENUE SW, SUITE 60
# 3        US     OK           TULSA       74116               11333 E. PINE ST
# 4        US     WA   POINT ROBERTS       98281             1361 PELTIER DRIVE
# 5        US     UT  SALT LAKE CITY       84101           C/O POULTON & YORDAN
# 6        US     UT          LINDON       84042        321 SOUTH 1250 WEST, #3
#
#                            bas2  ...    period      fy  fp     filed  \
# ...

# %%
df_sub2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 879 entries, 1 to 8042
# Data columns (total 36 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   adsh        879 non-null    object
#  1   cik         879 non-null    int64
#  2   name        879 non-null    object
#  3   sic         879 non-null    float64
#  4   countryba   877 non-null    object
#  5   stprba      787 non-null    object
#  6   cityba      877 non-null    object
#  7   zipba       875 non-null    object
#  8   bas1        877 non-null    object
#  9   bas2        359 non-null    object
#  10  baph        875 non-null    object
#  11  countryma   868 non-null    object
#  12  stprma      783 non-null    object
#  13  cityma      868 non-null    object
#  14  zipma       867 non-null    object
#  15  mas1        867 non-null    object
#  16  mas2        348 non-null    object
#  17  countryinc  798 non-null    object
#  18  stprinc     773 non-null    object
# ...

# %%
df_sub3 = pd.read_csv(r'd:\Універ М\Диплом - Дивідендна політика корпорації\03_01\SEC data {}q4\sub2.txt'.format(year_param), sep="\t")
df_sub3 = df_sub3[(df_sub3['fp']=='FY')]
df_sub3.head()
# Out:
#                    adsh     cik                                name     sic  \
# 0  0000004187-13-000010    4187  INDUSTRIAL SERVICES OF AMERICA INC  4950.0
# 1  0000013239-13-000012   13239  MOMENTIVE SPECIALTY CHEMICALS INC.  2821.0
# 2  0000061004-13-000014   61004                       LGL GROUP INC  3679.0
# 3  0000315858-13-000007  315858                  BFC FINANCIAL CORP  6035.0
# 4  0000706863-13-000008  706863                UNION BANKSHARES INC  6022.0
#
#   countryba stprba           cityba       zipba                    bas1  \
# 0        US     KY       LOUISVILLE       40232    7100 GRADE LN BLDG 4
# 1        US     OH         COLUMBUS       43215       180 EAST BROAD ST
# 2        US     FL          ORLANDO       32804        2525 SHADER ROAD
# 3        US     FL  FORT LAUDERDALE       33301  401 EAST LAS OLAS BLVD
# 4        US     VT      MORRISVILLE  05661-0667          20 MAIN STREET
#
# ...

# %%
df_sub3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2091 entries, 0 to 9113
# Data columns (total 36 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   adsh        2091 non-null   object
#  1   cik         2091 non-null   int64
#  2   name        2091 non-null   object
#  3   sic         2086 non-null   float64
#  4   countryba   2089 non-null   object
#  5   stprba      1738 non-null   object
#  6   cityba      2091 non-null   object
#  7   zipba       2079 non-null   object
#  8   bas1        2086 non-null   object
#  9   bas2        1027 non-null   object
#  10  baph        2076 non-null   object
#  11  countryma   2065 non-null   object
#  12  stprma      1730 non-null   object
#  13  cityma      2066 non-null   object
#  14  zipma       2064 non-null   object
#  15  mas1        2068 non-null   object
#  16  mas2        1010 non-null   object
#  17  countryinc  1840 non-null   object
#  18  stprinc     1677 non-null   object
# ...

# %%
df_sub4 = pd.read_csv(r'd:\Універ М\Диплом - Дивідендна політика корпорації\03_01\SEC data {}q4\sub1.txt'.format(year_param), sep="\t")
df_sub4 = df_sub4[(df_sub4['fp']=='FY')]
df_sub4.head()
# Out:
#                     adsh      cik                               name     sic  \
# 4   0001127855-13-000004  1157817           SINGLE TOUCH SYSTEMS INC  7389.0
# 9   0001213900-13-000002  1539447             LUCY'S WATER WORLD INC  8200.0
# 25  0001002014-13-000004  1126703     SHOSHONE SILVER/GOLD MINING CO  1040.0
# 30  0001144204-13-000679  1435508  FIRST SAVINGS FINANCIAL GROUP INC  6035.0
# 31  0001144204-13-000721  1421538      ABSOLUTE LIFE SOLUTIONS, INC.  6199.0
#
#    countryba stprba         cityba  zipba                            bas1  \
# 4         US     CA      ENCINITAS  92024  2235 ENCINITAS BLVD. SUITE 210
# 9         US     NV           RENO  89519    4790 CAUGHLIN PKWAY, STE 387
# 25        US     ID  COEUR D'ALENE  83815          5968 N. GOVERNMENT WAY
# 30        US     IN    CLARKSVILLE  47129  501 EAST LEWIS & CLARK PARKWAY
# 31        US     NY       NEW YORK  10006                     45 BROADWAY
#
# ...

# %%
df_sub4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4554 entries, 4 to 6793
# Data columns (total 36 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   adsh        4554 non-null   object
#  1   cik         4554 non-null   int64
#  2   name        4554 non-null   object
#  3   sic         4554 non-null   float64
#  4   countryba   4550 non-null   object
#  5   stprba      4305 non-null   object
#  6   cityba      4554 non-null   object
#  7   zipba       4532 non-null   object
#  8   bas1        4535 non-null   object
#  9   bas2        1956 non-null   object
#  10  baph        4519 non-null   object
#  11  countryma   4444 non-null   object
#  12  stprma      4216 non-null   object
#  13  cityma      4447 non-null   object
#  14  zipma       4444 non-null   object
#  15  mas1        4445 non-null   object
#  16  mas2        1899 non-null   object
#  17  countryinc  4135 non-null   object
#  18  stprinc     4008 non-null   object
# ...

# %%
df_union_sub = pd.concat([df_sub1, df_sub2, df_sub3, df_sub4])
df_union_sub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8319 entries, 3 to 6793
# Data columns (total 36 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   adsh        8319 non-null   object
#  1   cik         8319 non-null   int64
#  2   name        8319 non-null   object
#  3   sic         8312 non-null   float64
#  4   countryba   8308 non-null   object
#  5   stprba      7544 non-null   object
#  6   cityba      8314 non-null   object
#  7   zipba       8278 non-null   object
#  8   bas1        8290 non-null   object
#  9   bas2        3652 non-null   object
#  10  baph        8263 non-null   object
#  11  countryma   8168 non-null   object
#  12  stprma      7448 non-null   object
#  13  cityma      8172 non-null   object
#  14  zipma       8166 non-null   object
#  15  mas1        8171 non-null   object
#  16  mas2        3570 non-null   object
#  17  countryinc  7500 non-null   object
#  18  stprinc     7161 non-null   object
# ...

# %%
df_union_sub.to_excel('union.xlsx')

# %%
df_union_sub Medtronic

# %%
df['class'].str.contains('i', na=False)

# %%
df_union_sub = df_union_sub.set_index('cik')
df_joined = df_dividend_companies.join(df_union_sub, on='cik')
df_joined.head()
# Out:
#         Ticker                  adsh                 name     sic countryba  \
# cik
# 320193    AAPL  0001193125-13-416534            APPLE INC  3571.0        US
# 320193    AAPL  0001193125-13-170623            APPLE INC  3571.0        US
# 1551152   ABBV                   NaN                  NaN     NaN       NaN
# 1800       ABT  0001047469-13-001180  ABBOTT LABORATORIES  2834.0        US
# 1467373    ACN  0001467373-13-000482        ACCENTURE PLC  7389.0        IE
#
#         stprba       cityba       zipba                  bas1  \
# cik
# 320193      CA    CUPERTINO       95014     ONE INFINITE LOOP
# 320193      CA    CUPERTINO       95014     ONE INFINITE LOOP
# 1551152    NaN          NaN         NaN                   NaN
# 1800        IL  ABBOTT PARK  60064-3500  100 ABBOTT PARK ROAD
# 1467373    NaN       DUBLIN          D2  1 GRAND CANAL SQUARE
#
#                         bas2  ...      period      fy   fp       filed  \
# cik                           ...
# ...

# %%
df_joined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99 entries, 320193 to 18230
# Data columns (total 36 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Ticker      99 non-null     object
#  1   adsh        92 non-null     object
#  2   name        92 non-null     object
#  3   sic         92 non-null     float64
#  4   countryba   91 non-null     object
#  5   stprba      90 non-null     object
#  6   cityba      91 non-null     object
#  7   zipba       90 non-null     object
#  8   bas1        90 non-null     object
#  9   bas2        27 non-null     object
#  10  baph        90 non-null     object
#  11  countryma   90 non-null     object
#  12  stprma      89 non-null     object
#  13  cityma      90 non-null     object
#  14  zipma       90 non-null     object
#  15  mas1        90 non-null     object
#  16  mas2        26 non-null     object
#  17  countryinc  90 non-null     object
#  18  stprinc     89 non-null     object
# ...

# %%
df_joined.to_excel('test_companies.xlsx')

# %%
Medtronic
